# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
data=pd.read_excel("Final_Train.xlsx")
df=pd.DataFrame(data)
df.head()
# Out:
#                     Qualification           Experience Rating  \
# 0           BHMS, MD - Homeopathy  24 years experience   100%
# 1    BAMS, MD - Ayurveda Medicine  12 years experience    98%
# 2  MBBS, MS - Otorhinolaryngology   9 years experience    NaN
# 3             BSc - Zoology, BAMS  12 years experience    NaN
# 4                            BAMS  20 years experience   100%
#
#                           Place         Profile  \
# 0           Kakkanad, Ernakulam       Homeopath
# 1         Whitefield, Bangalore        Ayurveda
# 2    Mathikere - BEL, Bangalore  ENT Specialist
# 3  Bannerghatta Road, Bangalore        Ayurveda
# 4         Keelkattalai, Chennai        Ayurveda
#
#                                   Miscellaneous_Info  Fees
# 0               100% 16 Feedback Kakkanad, Ernakulam   100
# 1              98% 76 Feedback Whitefield, Bangalore   350
# 2                                                NaN   300
# 3  Bannerghatta Road, Bangalore ₹250 Available on...   250
# ...

# %%
df.shape
# Out:
# (5961, 7)

# %%
df.dtypes
# Out:
# Qualification         object
# Experience            object
# Rating                object
# Place                 object
# Profile               object
# Miscellaneous_Info    object
# Fees                   int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Qualification', 'Experience', 'Rating', 'Place', 'Profile',
#        'Miscellaneous_Info', 'Fees'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5961 entries, 0 to 5960
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Qualification       5961 non-null   object
#  1   Experience          5961 non-null   object
#  2   Rating              2659 non-null   object
#  3   Place               5936 non-null   object
#  4   Profile             5961 non-null   object
#  5   Miscellaneous_Info  3341 non-null   object
#  6   Fees                5961 non-null   int64
# dtypes: int64(1), object(6)
# memory usage: 326.1+ KB

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.isnull()
# Out:
#       Qualification  Experience  Rating  Place  Profile  Miscellaneous_Info  \
# 0             False       False   False  False    False               False
# 1             False       False   False  False    False               False
# 2             False       False    True  False    False                True
# 3             False       False    True  False    False               False
# 4             False       False   False  False    False               False
# ...             ...         ...     ...    ...      ...                 ...
# 5956          False       False   False  False    False               False
# 5957          False       False    True  False    False                True
# 5958          False       False   False  False    False               False
# 5959          False       False   False  False    False               False
# 5960          False       False   False  False    False               False
#
#        Fees
# 0     False
# 1     False
# 2     False
# ...

# %% [markdown]
# we have sum nulls values

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# the rating and miscellaneous_info which has more value of null

# %%
df.isnull().sum()
# Out:
# Qualification            0
# Experience               0
# Rating                3302
# Place                   25
# Profile                  0
# Miscellaneous_Info    2620
# Fees                     0
# dtype: int64

# %%
df.drop(['Miscellaneous_Info'],axis=1,inplace=True)   
df
# Out:
#                        Qualification           Experience Rating  \
# 0              BHMS, MD - Homeopathy  24 years experience   100%
# 1       BAMS, MD - Ayurveda Medicine  12 years experience    98%
# 2     MBBS, MS - Otorhinolaryngology   9 years experience    NaN
# 3                BSc - Zoology, BAMS  12 years experience    NaN
# 4                               BAMS  20 years experience   100%
# ...                              ...                  ...    ...
# 5956                  MBBS, MS - ENT  19 years experience    98%
# 5957                            MBBS  33 years experience    NaN
# 5958                            MBBS  41 years experience    97%
# 5959     MBBS, MD - General Medicine  15 years experience    90%
# 5960         BDS, MDS - Orthodontics  17 years experience   100%
#
#                               Place           Profile  Fees
# 0               Kakkanad, Ernakulam         Homeopath   100
# 1             Whitefield, Bangalore          Ayurveda   350
# ...

# %%
df['Rating'].fillna(value=df['Rating'].mode()[0],inplace=True)
df['Place'].fillna(value=df['Place'].mode()[0],inplace=True)
df
# Out:
#                        Qualification           Experience Rating  \
# 0              BHMS, MD - Homeopathy  24 years experience   100%
# 1       BAMS, MD - Ayurveda Medicine  12 years experience    98%
# 2     MBBS, MS - Otorhinolaryngology   9 years experience   100%
# 3                BSc - Zoology, BAMS  12 years experience   100%
# 4                               BAMS  20 years experience   100%
# ...                              ...                  ...    ...
# 5956                  MBBS, MS - ENT  19 years experience    98%
# 5957                            MBBS  33 years experience   100%
# 5958                            MBBS  41 years experience    97%
# 5959     MBBS, MD - General Medicine  15 years experience    90%
# 5960         BDS, MDS - Orthodontics  17 years experience   100%
#
#                               Place           Profile  Fees
# 0               Kakkanad, Ernakulam         Homeopath   100
# 1             Whitefield, Bangalore          Ayurveda   350
# ...

# %%
df.isnull().sum()
# Out:
# Qualification    0
# Experience       0
# Rating           0
# Place            0
# Profile          0
# Fees             0
# dtype: int64

# %% [markdown]
# we converting some of the columns into integer

# %%
for i in range(len(df)):
    df['Experience'][i]=df['Experience'][i][:-17]
    
df['Experience']=df['Experience'].astype(int)

# %%
for i in range(len(df)):
    df['Rating'][i]=df['Rating'][i][:-1]
    
df['Rating']=df['Rating'].astype(int)

# %%
df['Rating']=df['Rating']*0.1
df
# Out:
#                        Qualification  Experience  Rating  \
# 0              BHMS, MD - Homeopathy          24    1.00
# 1       BAMS, MD - Ayurveda Medicine          12    0.98
# 2     MBBS, MS - Otorhinolaryngology           9    1.00
# 3                BSc - Zoology, BAMS          12    1.00
# 4                               BAMS          20    1.00
# ...                              ...         ...     ...
# 5956                  MBBS, MS - ENT          19    0.98
# 5957                            MBBS          33    1.00
# 5958                            MBBS          41    0.97
# 5959     MBBS, MD - General Medicine          15    0.90
# 5960         BDS, MDS - Orthodontics          17    1.00
#
#                               Place           Profile  Fees
# 0               Kakkanad, Ernakulam         Homeopath   100
# 1             Whitefield, Bangalore          Ayurveda   350
# 2        Mathikere - BEL, Bangalore    ENT Specialist   300
# ...

# %%
df.dtypes
# Out:
# Qualification     object
# Experience         int32
# Rating           float64
# Place             object
# Profile           object
# Fees               int64
# dtype: object

# %%
df['Experience']=np.int64(df['Experience'])
df.dtypes
# Out:
# Qualification     object
# Experience         int64
# Rating           float64
# Place             object
# Profile           object
# Fees               int64
# dtype: object

# %%
for i in range(len(df)):
    df['Place'][i]=df['Place'][i].split(",")[-1]
    
df
# Out:
#                        Qualification  Experience  Rating       Place  \
# 0              BHMS, MD - Homeopathy          24    1.00   Ernakulam
# 1       BAMS, MD - Ayurveda Medicine          12    0.98   Bangalore
# 2     MBBS, MS - Otorhinolaryngology           9    1.00   Bangalore
# 3                BSc - Zoology, BAMS          12    1.00   Bangalore
# 4                               BAMS          20    1.00     Chennai
# ...                              ...         ...     ...         ...
# 5956                  MBBS, MS - ENT          19    0.98   Bangalore
# 5957                            MBBS          33    1.00     Chennai
# 5958                            MBBS          41    0.97       Delhi
# 5959     MBBS, MD - General Medicine          15    0.90      Mumbai
# 5960         BDS, MDS - Orthodontics          17    1.00       Delhi
#
#                Profile  Fees
# 0            Homeopath   100
# 1             Ayurveda   350
# 2       ENT Specialist   300
# ...

# %%
df.describe()
# Out:
#         Experience       Rating         Fees
# count  5961.000000  5961.000000  5961.000000
# mean     17.303976     0.976106   307.944640
# std      11.142798     0.058815   190.920373
# min       0.000000     0.070000     5.000000
# 25%       9.000000     0.980000   150.000000
# 50%      14.000000     1.000000   300.000000
# 75%      23.000000     1.000000   500.000000
# max      66.000000     1.000000   950.000000

# %%
df['Place'].value_counts()
# Out:
#  Bangalore             1283
#  Mumbai                1219
#  Delhi                 1185
#  Hyderabad              951
#  Chennai                855
#  Coimbatore             228
#  Ernakulam              153
#  Thiruvananthapuram      86
# e                         1
# Name: Place, dtype: int64

# %%
df=df[df['Place']!='e']
df['Place'].value_counts()
# Out:
#  Bangalore             1283
#  Mumbai                1219
#  Delhi                 1185
#  Hyderabad              951
#  Chennai                855
#  Coimbatore             228
#  Ernakulam              153
#  Thiruvananthapuram      86
# Name: Place, dtype: int64

# %%
df.shape
# Out:
# (5960, 6)

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Profile',data=df)
plt.title('Profile')
plt.show()
print(df['Profile'].value_counts())
# Out:
# Dentist             1396
# General Medicine    1173
# Dermatologists      1034
# Homeopath            843
# Ayurveda             786
# ENT Specialist       728
# Name: Profile, dtype: int64

# %% [markdown]
# Dentist which has the high value 1396
# and (Ayurveda and ENT specialist) which has the low value

# %%
plt.figure(figsize=(15,10))
plt.xticks(rotation=90)
sns.countplot(x='Experience',data=df)
plt.title('Experience')
plt.show()
print(df['Experience'].value_counts())
# Out:
# 9     323
# 10    294
# 11    288
# 8     282
# 12    279
#      ...
# 64      1
# 65      1
# 58      1
# 66      1
# 61      1
# Name: Experience, Length: 64, dtype: int64

# %% [markdown]
# the experience which has the high number of count

# %%
plt.figure(figsize=(15,10))
plt.xticks(rotation=90)
sns.countplot(x='Place',data=df)
plt.title('Place')
plt.show()
print(df['Place'].value_counts())
# Out:
#  Bangalore             1283
#  Mumbai                1219
#  Delhi                 1185
#  Hyderabad              951
#  Chennai                855
#  Coimbatore             228
#  Ernakulam              153
#  Thiruvananthapuram      86
# Name: Place, dtype: int64

# %% [markdown]
# the Bangalore which has the high number of count
# thiruvananthapuram has the low  points of count

# %% [markdown]
# plt.figure(figsize=(15,10))
# plt.xticks(rotation=90)
# sns.countplot(x='Rating',data=df)
# plt.title('Rating')
# plt.show()
# print(df['Rating'].value_counts())

# %% [markdown]
# the rating of 1.0 which has the 3985 count
# the .4 which has the 1 count

# %%
plt.figure(figsize=(15,10))
plt.xticks(rotation=90)
sns.countplot(x='Fees',data=df)
plt.title('Fees')
plt.show()
print(df['Fees'].value_counts())
# Out:
# 100    1306
# 500     938
# 200     904
# 300     864
# 400     424
# 250     306
# 150     253
# 600     215
# 700     153
# 800     143
# 350     143
# 50       81
# 450      65
# 750      34
# 550      22
# 650      21
# 900      18
# 70       18
# 80       12
# 60       11
# 30        4
# 10        2
# 260       2
# 130       2
# 180       2
# 40        2
# 380       2
# 220       1
# 280       1
# 499       1
# 5         1
# 920       1
# 299       1
# 125       1
# 230       1
# 430       1
# 630       1
# 850       1
# 950       1
# 20        1
# Name: Fees, dtype: int64

# %% [markdown]
# the fees of 100 which has the 1306 count
# the fees of 20,950,850,630,430,230,125,299,920,5,499,280,22, which has the 1 count

# %%
sns.catplot(x='Profile',y='Fees',data=df,kind='box',height=5,aspect=1.9)
plt.title('Profile vs Fees')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.xticks(rotation=90)
sns.scatterplot(x=df['Experience'],y=df['Fees'],data=df)
plt.title('Experience vs Fees')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.xticks(rotation=90)
sns.scatterplot(x=df['Rating'],y=df['Fees'],data=df)
plt.title('Rating vs Fees')
plt.show()

# %%
sns.catplot(x='Place',y='Fees',data=df,kind="box",height=5,aspect=2.0)
plt.title('Place vs Fees')
plt.show()

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
list1=['Place','Profile']
for val in list1:
    df[val]=le.fit_transform(df[val].astype(str))

# %%
df
# Out:
#                        Qualification  Experience  Rating  Place  Profile  Fees
# 0              BHMS, MD - Homeopathy          24    1.00      4        5   100
# 1       BAMS, MD - Ayurveda Medicine          12    0.98      0        0   350
# 2     MBBS, MS - Otorhinolaryngology           9    1.00      0        3   300
# 3                BSc - Zoology, BAMS          12    1.00      0        0   250
# 4                               BAMS          20    1.00      1        0   250
# ...                              ...         ...     ...    ...      ...   ...
# 5956                  MBBS, MS - ENT          19    0.98      0        3   300
# 5957                            MBBS          33    1.00      1        4   100
# 5958                            MBBS          41    0.97      3        4   600
# 5959     MBBS, MD - General Medicine          15    0.90      6        4   100
# 5960         BDS, MDS - Orthodontics          17    1.00      3        1   200
#
# [5960 rows x 6 columns]

# %%
df_corr=df.corr()
df_corr
# Out:
#             Experience    Rating     Place   Profile      Fees
# Experience    1.000000 -0.149635  0.039062  0.202165  0.002143
# Rating       -0.149635  1.000000  0.064414 -0.046958 -0.154696
# Place         0.039062  0.064414  1.000000 -0.010916 -0.020266
# Profile       0.202165 -0.046958 -0.010916  1.000000  0.145192
# Fees          0.002143 -0.154696 -0.020266  0.145192  1.000000

# %%
sns.heatmap(df_corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
df['Qualification'].unique()
# Out:
# array(['BHMS, MD - Homeopathy', 'BAMS, MD - Ayurveda Medicine',
#        'MBBS, MS - Otorhinolaryngology', ...,
#        'MD - Dermatology , Venereology & Leprosy, MBBS, Fellowship In Dermatosurgery',
#        'BDS, certification in smile designing',
#        'MD - Homeopathy, Post Graduate Diploma in Healthcare Management(PGDHM), DHMS (Diploma in Homeopathic Medicine and Surgery)'],
#       dtype=object)

# %%
df['Qualification']=df['Qualification'].str.split(",")
df['Qualification'].values
# Out:
# array([list(['BHMS', ' MD - Homeopathy']),
#        list(['BAMS', ' MD - Ayurveda Medicine']),
#        list(['MBBS', ' MS - Otorhinolaryngology']), ..., list(['MBBS']),
#        list(['MBBS', ' MD - General Medicine']),
#        list(['BDS', ' MDS - Orthodontics'])], dtype=object)

# %%
Qual={}

for x in df['Qualification'].values:
    for each in x:
        each=each.strip()
        if each in Qual:
            Qual[each]+=1
        else:
            Qual[each]=1
            
print(Qual)
# Out:
# {'BHMS': 749, 'MD - Homeopathy': 181, 'BAMS': 764, 'MD - Ayurveda Medicine': 139, 'MBBS': 2808, 'MS - Otorhinolaryngology': 103, 'BSc - Zoology': 3, 'BDS': 1362, 'MD - General Medicine': 285, 'BSc': 3, 'MS': 2, 'DNB - ENT': 111, 'MDS': 82, 'MDS - Oral & Maxillofacial Surgery': 104, 'Diploma in Otorhinolaryngology (DLO)': 250, 'MF- Homeopathy': 5, 'MS - ENT': 411, 'DNB': 58, 'Fellowship of College of General Practice (FCGP)': 13, 'DDVL': 161, 'IBCLC (USA)': 1, 'Post Graduate Diploma in Diabetology (PGDD)': 53, 'Diploma in Dermatology': 67, 'Fellowship in Aesthetic Medicine': 23, 'DM - Neurology': 6, 'MD - Pediatrics': 13, 'Fellowship in Cleft Lip and Craniofacial Surgery': 1, 'Diploma in Cosmetology': 3, 'AFIH': 4, 'MDS - Prosthodontist And Crown Bridge': 45, 'M. D. Hom. (Practice of Medicine)': 2, 'Diploma in Emergency Medicine': 8, 'Diploma in Counselling Skills': 2, 'DHMS (Diploma in Homeopathic Medicine and Surgery)': 47, 'MD - Dermatology': 606, 'Venereology & Leprosy': 297, 'MDS
# ...

# %%
most_qual=sorted(Qual.items(),key=lambda x:x[1],reverse=True)[:10]
most_qual
# Out:
# [('MBBS', 2808),
#  ('BDS', 1362),
#  ('BAMS', 764),
#  ('BHMS', 749),
#  ('MD - Dermatology', 606),
#  ('MS - ENT', 411),
#  ('Venereology & Leprosy', 297),
#  ('MD - General Medicine', 285),
#  ('Diploma in Otorhinolaryngology (DLO)', 250),
#  ('MD - Homeopathy', 181)]

# %%
final_qual=[]
for q in most_qual:
    final_qual.append(q[0])

print(final_qual)
# Out:
# ['MBBS', 'BDS', 'BAMS', 'BHMS', 'MD - Dermatology', 'MS - ENT', 'Venereology & Leprosy', 'MD - General Medicine', 'Diploma in Otorhinolaryngology (DLO)', 'MD - Homeopathy']

# %%
for q in final_qual:
    df[q]=0
    
for x,y in zip(df['Qualification'].values,np.array([i for i in range(len(df))])):
    for c in x:
        c=c.strip()
        if c in final_qual:
            df[c][y]=1

# %%
df
# Out:
#                           Qualification  Experience  Rating  Place  Profile  \
# 0              [BHMS,  MD - Homeopathy]          24    1.00      4        5
# 1       [BAMS,  MD - Ayurveda Medicine]          12    0.98      0        0
# 2     [MBBS,  MS - Otorhinolaryngology]           9    1.00      0        3
# 3                [BSc - Zoology,  BAMS]          12    1.00      0        0
# 4                                [BAMS]          20    1.00      1        0
# ...                                 ...         ...     ...    ...      ...
# 5956                  [MBBS,  MS - ENT]          19    0.98      0        3
# 5957                             [MBBS]          33    1.00      1        4
# 5958                             [MBBS]          41    0.97      3        4
# 5959     [MBBS,  MD - General Medicine]          15    0.90      6        4
# 5960         [BDS,  MDS - Orthodontics]          17    1.00      3        1
#
# ...

# %%
df.drop(['Qualification'],axis=1,inplace=True)
df
# Out:
#       Experience  Rating  Place  Profile  Fees  MBBS  BDS  BAMS  BHMS  \
# 0             24    1.00      4        5   100     0    0     0     1
# 1             12    0.98      0        0   350     0    0     1     0
# 2              9    1.00      0        3   300     1    0     0     0
# 3             12    1.00      0        0   250     0    0     1     0
# 4             20    1.00      1        0   250     0    0     1     0
# ...          ...     ...    ...      ...   ...   ...  ...   ...   ...
# 5956          19    0.98      0        3   300     1    0     0     0
# 5957          33    1.00      1        4   100     1    0     0     0
# 5958          41    0.97      3        4   600     1    0     0     0
# 5959          15    0.90      6        4   100     0    1     0     0
# 5960          17    1.00      3        1   200     0    0     0     0
#
#       MD - Dermatology  MS - ENT  Venereology & Leprosy  \
# 0                    0         0                      0
# ...

# %%
x=df.drop(['Fees'],axis=1)
x
# Out:
#       Experience  Rating  Place  Profile  MBBS  BDS  BAMS  BHMS  \
# 0             24    1.00      4        5     0    0     0     1
# 1             12    0.98      0        0     0    0     1     0
# 2              9    1.00      0        3     1    0     0     0
# 3             12    1.00      0        0     0    0     1     0
# 4             20    1.00      1        0     0    0     1     0
# ...          ...     ...    ...      ...   ...  ...   ...   ...
# 5956          19    0.98      0        3     1    0     0     0
# 5957          33    1.00      1        4     1    0     0     0
# 5958          41    0.97      3        4     1    0     0     0
# 5959          15    0.90      6        4     0    1     0     0
# 5960          17    1.00      3        1     0    0     0     0
#
#       MD - Dermatology  MS - ENT  Venereology & Leprosy  \
# 0                    0         0                      0
# 1                    0         0                      0
# ...

# %%
y=pd.DataFrame(df['Fees'])
y
# Out:
#       Fees
# 0      100
# 1      350
# 2      300
# 3      250
# 4      250
# ...    ...
# 5956   300
# 5957   100
# 5958   600
# 5959   100
# 5960   200
#
# [5960 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
best_r_state=0
accu=0

for i in range(30,200):
    train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.30,random_state=i)
    mod=LinearRegression()
    mod.fit(train_x,train_y)
    pred_y=mod.predict(test_x)
    tempaccu=r2_score(test_y,pred_y)
    if tempaccu>accu:
        accu=tempaccu
        best_r_state=i

print(f"Best random_state {best_r_state}")
# Out:
# Best random_state 108

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from sklearn.linear_model import Lasso,Ridge,ElasticNet
from sklearn.metrics import r2_score, mean_squared_error,mean_absolute_error

train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.30,random_state=108)
model=[LinearRegression(),KNeighborsRegressor(),SVR(),RandomForestRegressor(),AdaBoostRegressor(),
       GradientBoostingRegressor(),Lasso(),Ridge(),ElasticNet()]

for m in model:
    m.fit(train_x,train_y)
    m_y=m.predict(test_x)
    print("Score of Model",m,"is",m.score(train_x,train_y))
  
    print("Mean Absolute Error", mean_absolute_error(test_y,m_y))
    print("Root Mean Squared Error", (mean_squared_error(test_y,m_y))**0.5 )
   
    print("\n\n")
# Out:
# Score of Model LinearRegression() is 0.06915210078496137
# Mean Absolute Error 148.51257433735748
# Root Mean Squared Error 182.98634905344042
#
#
#
# Score of Model KNeighborsRegressor() is 0.323374709485849
# Mean Absolute Error 148.26778523489935
# Root Mean Squared Error 190.581024945694
#
#
#
# Score of Model SVR() is 0.00017487540215943564
# Mean Absolute Error 154.20248598581142
# Root Mean Squared Error 194.03204251718952
#
#
#
# Score of Model RandomForestRegressor() is 0.7308480930124921
# Mean Absolute Error 145.54713163485033
# Root Mean Squared Error 189.62643119914003
#
#
#
# Score of Model AdaBoostRegressor() is 0.11248336062505848
# Mean Absolute Error 147.4497125216621
# Root Mean Squared Error 179.5698502254089
#
#
#
# Score of Model GradientBoostingRegressor() is 0.22648570229125176
# Mean Absolute Error 136.46630140948875
# Root Mean Squared Error 172.92899527304826
#
#
#
# Score of Model Lasso() is 0.05800540078877636
# Mean Absolute Error 151.3221220109836
# ...

# %%
from sklearn.model_selection import GridSearchCV
rfr=RandomForestRegressor()
parameters={'n_estimators':[100,200,300,400,500]}
reg=GridSearchCV(rfr,parameters)
reg.fit(x,y)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'n_estimators': [100, 200, 300, 400, 500]})

# %%
print(reg.best_params_)
# Out:
# {'n_estimators': 400}

# %%
rfr=RandomForestRegressor(n_estimators=500) #parameters given from GridSearchCV method.
rfr.fit(train_x,train_y)
rfr.score(train_x,train_y)
rfr_y=rfr.predict(test_x)
print("Score of Model is",rfr.score(train_x,train_y))
print("Mean Absolute Error", mean_absolute_error(test_y,rfr_y))
print("Root Mean Squared Error", (mean_squared_error(test_y,rfr_y))**0.5 )
# Out:
# Score of Model is 0.733352703617904
# Mean Absolute Error 144.7517416452711
# Root Mean Squared Error 189.00374404170336

# %%
import pandas as pd
data=pd.read_excel("Final_Test.xlsx")
df1=pd.DataFrame(data)
df.head()
# Out:
#                                      Qualification           Experience  \
# 0                                             MBBS  35 years experience
# 1       MBBS, Diploma in Otorhinolaryngology (DLO)  31 years experience
# 2                                       MBBS, DDVL  40 years experience
# 3                                             BAMS   0 years experience
# 4  BDS, MDS - Conservative Dentistry & Endodontics  16 years experience
#
#   Rating                        Place           Profile  \
# 0    NaN       Ghatkopar East, Mumbai  General Medicine
# 1    NaN  West Marredpally, Hyderabad    ENT Specialist
# 2    70%            KK Nagar, Chennai    Dermatologists
# 3    NaN       New Ashok Nagar, Delhi          Ayurveda
# 4   100%    Kanakpura Road, Bangalore           Dentist
#
#                                   Miscellaneous_Info
# 0                                                NaN
# 1                                                NaN
# ...

# %%
df1.isnull().sum()
# Out:
# Qualification            0
# Experience               0
# Rating                1090
# Place                    6
# Profile                  0
# Miscellaneous_Info     834
# dtype: int64

# %%
df1.shape
# Out:
# (1987, 6)

# %%
df1.drop(['Miscellaneous_Info'],axis=1,inplace=True)   
df1
# Out:
#                                         Qualification           Experience  \
# 0                                                MBBS  35 years experience
# 1          MBBS, Diploma in Otorhinolaryngology (DLO)  31 years experience
# 2                                          MBBS, DDVL  40 years experience
# 3                                                BAMS   0 years experience
# 4     BDS, MDS - Conservative Dentistry & Endodontics  16 years experience
# ...                                               ...                  ...
# 1982                         BAMS, Doctor of Medicine  10 years experience
# 1983   MD - Dermatology , Venereology & Leprosy, MBBS   4 years experience
# 1984         MBBS, MD / MS - Obstetrics & Gynaecology   9 years experience
# 1985                                              BDS  12 years experience
# 1986   MBBS, MD - Dermatology , Venereology & Leprosy   8 years experience
#
#      Rating                        Place           Profile
# ...

# %%
df1['Rating'].fillna(value=df1['Rating'].mode()[0],inplace=True)
df1['Place'].fillna(value=df1['Place'].mode()[0],inplace=True)
df1
# Out:
#                                         Qualification           Experience  \
# 0                                                MBBS  35 years experience
# 1          MBBS, Diploma in Otorhinolaryngology (DLO)  31 years experience
# 2                                          MBBS, DDVL  40 years experience
# 3                                                BAMS   0 years experience
# 4     BDS, MDS - Conservative Dentistry & Endodontics  16 years experience
# ...                                               ...                  ...
# 1982                         BAMS, Doctor of Medicine  10 years experience
# 1983   MD - Dermatology , Venereology & Leprosy, MBBS   4 years experience
# 1984         MBBS, MD / MS - Obstetrics & Gynaecology   9 years experience
# 1985                                              BDS  12 years experience
# 1986   MBBS, MD - Dermatology , Venereology & Leprosy   8 years experience
#
#      Rating                        Place           Profile
# ...

# %%
df1.isnull().sum()
# Out:
# Qualification    0
# Experience       0
# Rating           0
# Place            0
# Profile          0
# dtype: int64

# %%
for i in range(len(df1)):
    df1['Experience'][i]=df1['Experience'][i][:-17]
    
df1['Experience']=df1['Experience'].astype(int)

# %%
for i in range(len(df1)):
    df1['Rating'][i]=df1['Rating'][i][:-1]
    
df1['Rating']=df1['Rating'].astype(int)

# %%
df1['Rating']=df1['Rating']*0.1
df1
# Out:
#                                         Qualification  Experience  Rating  \
# 0                                                MBBS          35    10.0
# 1          MBBS, Diploma in Otorhinolaryngology (DLO)          31    10.0
# 2                                          MBBS, DDVL          40     7.0
# 3                                                BAMS           0    10.0
# 4     BDS, MDS - Conservative Dentistry & Endodontics          16    10.0
# ...                                               ...         ...     ...
# 1982                         BAMS, Doctor of Medicine          10    10.0
# 1983   MD - Dermatology , Venereology & Leprosy, MBBS           4    10.0
# 1984         MBBS, MD / MS - Obstetrics & Gynaecology           9    10.0
# 1985                                              BDS          12     9.8
# 1986   MBBS, MD - Dermatology , Venereology & Leprosy           8    10.0
#
#                             Place           Profile
# ...

# %%
df1.dtypes
# Out:
# Qualification     object
# Experience         int32
# Rating           float64
# Place             object
# Profile           object
# dtype: object

# %%
df1['Experience']=np.int64(df1['Experience'])
df1.dtypes
# Out:
# Qualification     object
# Experience         int64
# Rating           float64
# Place             object
# Profile           object
# dtype: object

# %%
for i in range(len(df1)):
    df1['Place'][i]=df1['Place'][i].split(",")[-1]
    
df1
# Out:
#                                         Qualification  Experience  Rating  \
# 0                                                MBBS          35    10.0
# 1          MBBS, Diploma in Otorhinolaryngology (DLO)          31    10.0
# 2                                          MBBS, DDVL          40     7.0
# 3                                                BAMS           0    10.0
# 4     BDS, MDS - Conservative Dentistry & Endodontics          16    10.0
# ...                                               ...         ...     ...
# 1982                         BAMS, Doctor of Medicine          10    10.0
# 1983   MD - Dermatology , Venereology & Leprosy, MBBS           4    10.0
# 1984         MBBS, MD / MS - Obstetrics & Gynaecology           9    10.0
# 1985                                              BDS          12     9.8
# 1986   MBBS, MD - Dermatology , Venereology & Leprosy           8    10.0
#
#            Place           Profile
# 0         Mumbai  General Medicine
# ...

# %%
df1['Place'].value_counts()
# Out:
#  Bangalore             420
#  Delhi                 417
#  Mumbai                395
#  Hyderabad             333
#  Chennai               287
#  Coimbatore             70
#  Ernakulam              48
#  Thiruvananthapuram     17
# Name: Place, dtype: int64

# %%
df1['Profile'].value_counts()
# Out:
# General Medicine    444
# Dentist             441
# Dermatologists      339
# Homeopath           277
# Ayurveda            251
# ENT Specialist      235
# Name: Profile, dtype: int64

# %%
df1['Experience'].unique()
# Out:
# array([35, 31, 40,  0, 16, 14, 23,  9, 11, 44,  4, 34, 13, 28,  6, 32,  3,
#         8, 43, 27, 22, 25, 36, 17, 20, 18, 29,  5, 19, 10,  2, 30, 24, 26,
#        41, 46, 21, 12, 45, 33, 38,  7, 59, 15, 39, 42, 54, 49, 48, 52, 51,
#        50, 37, 47, 53, 56, 65], dtype=int64)

# %%
df1['Rating'].unique()
# Out:
# array([10. ,  7. ,  9. ,  9.4,  9.9,  9.8,  8.7,  6.4,  9.6,  9.5,  9.7,
#         9.3,  6.9,  7.1,  8.3,  9.2,  8. ,  8.6,  8.8,  6.7,  8.5,  8.4,
#         5.5,  8.9,  8.2,  8.1,  6. ,  7.3,  6.5,  7.7,  9.1,  7.8,  7.9,
#         7.6,  5.2,  5.3])

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
list1=['Place','Profile']
for val in list1:
    df1[val]=le.fit_transform(df1[val].astype(str))

# %%
df1
# Out:
#                                         Qualification  Experience  Rating  \
# 0                                                MBBS          35    10.0
# 1          MBBS, Diploma in Otorhinolaryngology (DLO)          31    10.0
# 2                                          MBBS, DDVL          40     7.0
# 3                                                BAMS           0    10.0
# 4     BDS, MDS - Conservative Dentistry & Endodontics          16    10.0
# ...                                               ...         ...     ...
# 1982                         BAMS, Doctor of Medicine          10    10.0
# 1983   MD - Dermatology , Venereology & Leprosy, MBBS           4    10.0
# 1984         MBBS, MD / MS - Obstetrics & Gynaecology           9    10.0
# 1985                                              BDS          12     9.8
# 1986   MBBS, MD - Dermatology , Venereology & Leprosy           8    10.0
#
#       Place  Profile
# 0         6        4
# 1         5        3
# ...

# %%
df1['Qualification'].unique()
# Out:
# array(['MBBS', 'MBBS, Diploma in Otorhinolaryngology (DLO)', 'MBBS, DDVL',
#        'BAMS', 'BDS, MDS - Conservative Dentistry & Endodontics',
#        'BDS, MDS', 'BDS, MDS - Pedodontics',
#        'MD - Ayurveda Medicine, BAMS, Yoga Teachers Training Course, M. D. IN KAYACHIKISTA',
#        'BHMS', 'BDS', 'MBBS, FCD - Diabetology', 'MBBS, DDV',
#        'MBBS, MD - Dermatology', 'MS - ENT',
#        'MBBS, Diploma in Otorhinolaryngology (DLO), MS - ENT, DNB - ENT, MNAMS (Membership of the National Academy)',
#        'BHMS, Diploma in Naturopathy & Yogic Science (DNYS), Diploma in Diet and Nutrition, Diploma in Cosmetology',
#        'MBBS, PG Diploma In Clinical Cosmetology (PGDCC)',
#        'BDS, MDS - Periodontics', 'BDS, MDS- Oral Pathology',
#        'MBBS, MD - General Medicine', 'MS - ENT, MBBS',
#        'MBBS, Diploma in Otorhinolaryngology (DLO), DNB - ENT',
#        'MBBS, MS - ENT, DNB - Otorhinolaryngology',
# ...

# %%
df1['Qualification']=df1['Qualification'].str.split(",")
df1['Qualification'].values
# Out:
# array([list(['MBBS']),
#        list(['MBBS', ' Diploma in Otorhinolaryngology (DLO)']),
#        list(['MBBS', ' DDVL']), ...,
#        list(['MBBS', ' MD / MS - Obstetrics & Gynaecology']),
#        list(['BDS']),
#        list(['MBBS', ' MD - Dermatology ', ' Venereology & Leprosy'])],
#       dtype=object)

# %%
Qual_test={}

for y in df1['Qualification'].values:
    for each_t in y:
        each_t=each_t.strip()
        if each_t in Qual_test:
            Qual_test[each_t]+=1
        else:
            Qual_test[each_t]=1
            
print(Qual_test)
# Out:
# {'MBBS': 980, 'Diploma in Otorhinolaryngology (DLO)': 85, 'DDVL': 67, 'BAMS': 243, 'BDS': 428, 'MDS - Conservative Dentistry & Endodontics': 34, 'MDS': 21, 'MDS - Pedodontics': 10, 'MD - Ayurveda Medicine': 41, 'Yoga Teachers Training Course': 2, 'M. D. IN KAYACHIKISTA': 2, 'BHMS': 249, 'FCD - Diabetology': 2, 'DDV': 38, 'MD - Dermatology': 196, 'MS - ENT': 128, 'DNB - ENT': 39, 'MNAMS (Membership of the National Academy)': 3, 'Diploma in Naturopathy & Yogic Science (DNYS)': 1, 'Diploma in Diet and Nutrition': 4, 'Diploma in Cosmetology': 5, 'PG Diploma In Clinical Cosmetology (PGDCC)': 4, 'MDS - Periodontics': 13, 'MDS- Oral Pathology': 1, 'MD - General Medicine': 99, 'DNB - Otorhinolaryngology': 15, 'PhD - Endodontics': 1, 'BSc': 3, 'LCEH': 6, 'DGO': 4, 'MD - Obstetrics & Gynaecology': 5, 'MD - Homeopathy': 62, 'DM - Oncology': 1, 'DNB - Dermatology': 5, 'Venereology & Leprosy': 91, 'DVD': 11, 'MS - Otorhinolaryngology': 42, 'Fellowship in Aesthetic Medicine': 5, 'Fellowship in Ora
# ...

# %%
most_qual_test=sorted(Qual_test.items(),key=lambda x:x[1],reverse=True)[:10]
most_qual_test
# Out:
# [('MBBS', 980),
#  ('BDS', 428),
#  ('BHMS', 249),
#  ('BAMS', 243),
#  ('MD - Dermatology', 196),
#  ('MS - ENT', 128),
#  ('MD - General Medicine', 99),
#  ('Venereology & Leprosy', 91),
#  ('Diploma in Otorhinolaryngology (DLO)', 85),
#  ('DDVL', 67)]

# %%
final_qual_test=[]
for qt in most_qual_test:
    final_qual_test.append(qt[0])

print(final_qual_test)
# Out:
# ['MBBS', 'BDS', 'BHMS', 'BAMS', 'MD - Dermatology', 'MS - ENT', 'MD - General Medicine', 'Venereology & Leprosy', 'Diploma in Otorhinolaryngology (DLO)', 'DDVL']

# %%
for qft in final_qual_test:
    df1[qft]=0
    
for x,y in zip(df1['Qualification'].values,np.array([i for i in range(len(df1))])):
    for c in x:
        c=c.strip()
        if c in final_qual_test:
            df1[c][y]=1

# %%
df1
# Out:
#                                           Qualification  Experience  Rating  \
# 0                                                [MBBS]          35    10.0
# 1         [MBBS,  Diploma in Otorhinolaryngology (DLO)]          31    10.0
# 2                                         [MBBS,  DDVL]          40     7.0
# 3                                                [BAMS]           0    10.0
# 4     [BDS,  MDS - Conservative Dentistry & Endodont...          16    10.0
# ...                                                 ...         ...     ...
# 1982                        [BAMS,  Doctor of Medicine]          10    10.0
# 1983  [MD - Dermatology ,  Venereology & Leprosy,  M...           4    10.0
# 1984        [MBBS,  MD / MS - Obstetrics & Gynaecology]           9    10.0
# 1985                                              [BDS]          12     9.8
# 1986  [MBBS,  MD - Dermatology ,  Venereology & Lepr...           8    10.0
#
# ...

# %%
df1.drop(['Qualification'],axis=1,inplace=True)
df1
# Out:
#       Experience  Rating  Place  Profile  MBBS  BDS  BHMS  BAMS  \
# 0             35    10.0      6        4     1    0     0     0
# 1             31    10.0      5        3     1    0     0     0
# 2             40     7.0      1        2     1    0     0     0
# 3              0    10.0      3        0     0    0     0     1
# 4             16    10.0      0        1     0    1     0     0
# ...          ...     ...    ...      ...   ...  ...   ...   ...
# 1982          10    10.0      0        0     0    0     0     1
# 1983           4    10.0      1        2     1    0     0     0
# 1984           9    10.0      1        4     1    0     0     0
# 1985          12     9.8      0        1     0    1     0     0
# 1986           8    10.0      1        2     1    0     0     0
#
#       MD - Dermatology  MS - ENT  MD - General Medicine  \
# 0                    0         0                      0
# 1                    0         0                      0
# ...

# %%
rfr_pred=rfr.predict(df1)
rfr_pred
# Out:
# array([201.17825397, 284.4       , 362.21333333, ..., 197.81333333,
#        248.99095238, 597.07666667])

# %%
rfr_pred=pd.DataFrame(rfr_pred, columns=['Fees'])
rfr_pred
# Out:
#             Fees
# 0     201.178254
# 1     284.400000
# 2     362.213333
# 3     199.663095
# 4     447.173333
# ...          ...
# 1982  284.980916
# 1983  535.031905
# 1984  197.813333
# 1985  248.990952
# 1986  597.076667
#
# [1987 rows x 1 columns]
